# %%
import os
os.chdir("/content/drive/MyDrive/building_segmentation")
print(os.getcwd())
# Out:
# /content/drive/MyDrive/building_segmentation

# %%
# !pip install ultralytics==8.0.28
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.0/78.2 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt data=/content/drive/MyDrive/building_segmentation/building_data/data.yaml epochs=10 imgsz=640 save=true
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/drive/MyDrive/building_segmentation/runs/segment/train4/confusion_matrix.png', width=600)

# %%
Image(filename=f'/content/drive/MyDrive/leukemia/runs/segment/train4/results.png', width=600)

# %%
Image(filename=f'/content/drive/MyDrive/building_segmentation/runs/segment/train4/train_batch0.jpg', width=600)
